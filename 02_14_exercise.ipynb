# %%
# Create a function to open and read in daily mean temperature for NYC Central Park (2010) from a
# .txt file. Using the readlines command to make the output a list.
def read_text(file):
    with open(file, 'r') as data:
        sat = data.readlines()
    return sat

# %%
# Print the observed NYC temperature to the screen
def print_data(obs):
    day_of_year = [str(k) for k in range(1, 366)]
    day_of_year.insert(0, 'Day of Year\n(1-365)')
    temp_column = ['Temperature Observation\n(Degrees Fahrenheit)'] + obs
# Zip the two lists together for easier printing
    combined_data = list(zip(day_of_year, temp_column))
    
# this null function is passed the temperature data. The function prints to the screen two columns with headers:
    # - one column indicating the day of the year (1-365),
    # - and a second column indicating the temperature observation for each day.
# Be sure to indicate the units of the temperature data (°F)

    for item in combined_data:
        print('\t'.join(item))
    return

# %%
# Main Routine (Exercise 1 - 02/14)

# First, specify the file name that has already been included in the same folder:
file_text = 'nyc_temp_2010.txt'
    # this text file contains the daily mean temperatures for NYC Central Park (2010)

# Now call the functions (read and print):
sat_nyc_2010 = read_text(file_text)
    # this function is passed the file name, reads in the temperature data, and returns the data

print_data(sat_nyc_2010)
# Out:
# Day of Year
# (1-365)	Temperature Observation
# (Degrees Fahrenheit)
# 1	37
#
# 2	26
#
# 3	20
#
# 4	25
#
# 5	25
#
# 6	30
#
# 7	34
#
# 8	28
#
# 9	24
#
# 10	21
#
# 11	26
#
# 12	30
#
# 13	30
#
# 14	36
#
# 15	43
#
# 16	44
#
# 17	41
#
# 18	44
#
# 19	44
#
# 20	38
#
# 21	36
#
# 22	38
#
# 23	34
#
# 24	41
#
# 25	53
#
# 26	42
#
# 27	35
#
# 28	31
#
# 29	20
#
# 30	17
#
# 31	22
#
# 32	30
#
# 33	30
#
# 34	34
#
# 35	33
#
# 36	33
#
# 37	27
#
# 38	26
#
# 39	30
#
# 40	35
#
# 41	32
#
# 42	33
#
# 43	32
#
# 44	28
#
# 45	34
#
# 46	34
#
# 47	31
#
# 48	31
#
# 49	36
#
# 50	39
#
# 51	40
#
# 52	40
#
# 53	37
#
# 54	37
#
# 55	39
#
# 56	33
#
# 57	30
#
# 58	34
#
# 59	37
#
# 60	42
#
# 61	42
#
# 62	38
#
# 63	41
#
# 64	42
#
# 65	43
#
# 66	47
#
# 67	51
#
# 68	53
#
# 69	51
#
# 70	48
#
# 71	41
#
# 72	42
#
# 73	47
#
# 74	44
#
# 75	52
#
# 76	55
#
# 77	60
#
# 78	61
#
# 79	64
#
# 80	58
#
# 81	54
#
# 82	49
#
# 83	52
#
# 84	55
#
# 85	43
#
# 86	37
#
# 87	43
#
# 88	51
#
# 89	46
#
# 90	51
#
# 91	59
#
# 92	58
#
# 93	57
#
# 94	62
#
# 95	66
#
# 96	68
#
# 97	74
#
# 98	72
#
# 99	56
#
# 100	52
#
# 101	64
#
# 102	60
#
# 103	52
#
# 104	56
#
# 105	62
#
# 106	52
#
# 107	50
#
# 108	50
#
# 109	55
#
# 110	59
#
# 111	61
#
# 112	62
#
# 113	56
#
# 114	57
#
# 115	49
#
# 116	51
#
# 117	50
#
# 118	48
#
# 119	57
#
# 120	67
#
# 121	75
#
# 122	77
#
# 123	74
#
# 124	72
#
# 125	69
#
# 126	69
#
# 127	63
#
# 128	63
#
# 129	48
#
# 130	51
#
# 131	50
#
# 132	46
#
# 133	55
#
# 134	68
#
# 135	67
#
# 136	63
#
# 137	65
#
# 138	56
#
# 139	57
#
# 140	67
#
# 141	73
#
# 142	66
#
# 143	65
#
# 144	67
#
# 145	72
#
# 146	79
#
# 147	69
#
# 148	63
#
# 149	69
#
# 150	76
#
# 151	78
#
# 152	76
#
# 153	77
#
# 154	77
#
# 155	80
#
# 156	82
#
# 157	75
#
# 158	66
#
# 159	67
#
# 160	63
#
# 161	66
#
# 162	65
#
# 163	70
#
# 164	72
#
# 165	72
#
# 166	73
#
# 167	70
#
# 168	70
#
# 169	73
#
# 170	73
#
# 171	80
#
# 172	79
#
# 173	79
#
# 174	80
#
# 175	84
#
# 176	79
#
# 177	80
#
# 178	81
#
# 179	85
#
# 180	81
#
# 181	71
#
# 182	70
#
# 183	72
#
# 184	77
#
# 185	85
#
# 186	88
#
# 187	92
#
# 188	90
#
# 189	83
#
# 190	83
#
# 191	78
#
# 192	83
#
# 193	84
#
# 194	78
#
# 195	76
#
# 196	80
#
# 197	84
#
# 198	85
#
# 199	86
#
# 200	82
#
# 201	82
#
# 202	85
#
# 203	82
#
# 204	80
#
# 205	89
#
# 206	82
#
# 207	78
#
# 208	81
#
# 209	82
#
# 210	82
#
# 211	76
#
# 212	76
#
# 213	75
#
# 214	77
#
# 215	79
#
# 216	83
#
# 217	86
#
# 218	80
#
# 219	78
#
# 220	81
#
# 221	84
#
# 222	85
#
# 223	85
#
# 224	72
#
# 225	75
#
# 226	74
#
# 227	72
#
# 228	78
#
# 229	83
#
# 230	79
#
# 231	80
#
# 232	82
#
# 233	76
#
# 234	75
#
# 235	68
#
# 236	67
#
# 237	67
#
# 238	74
#
# 239	70
#
# 240	73
#
# 241	81
#
# 242	82
#
# 243	86
#
# 244	86
#
# 245	86
#
# 246	80
#
# 247	73
#
# 248	70
#
# 249	70
#
# 250	79
#
# 251	78
#
# 252	66
#
# 253	68
#
# 254	69
#
# 255	63
#
# 256	68
#
# 257	68
#
# 258	65
#
# 259	65
#
# 260	65
#
# 261	64
#
# 262	71
#
# 263	67
#
# 264	64
#
# 265	76
#
# 266	74
#
# 267	76
#
# 268	78
#
# 269	68
#
# 270	67
#
# 271	72
#
# 272	71
#
# 273	72
#
# 274	67
#
# 275	59
#
# 276	57
#
# 277	54
#
# 278	57
#
# 279	59
#
# 280	62
#
# 281	64
#
# 282	63
#
# 283	58
#
# 284	66
#
# 285	62
#
# 286	56
#
# 287	57
#
# 288	53
#
# 289	54
#
# 290	59
#
# 291	55
#
# 292	53
#
# 293	53
#
# 294	56
#
# 295	50
#
# 296	54
#
# 297	61
#
# 298	64
#
# 299	68
#
# 300	70
#
# 301	65
#
# 302	52
#
# 303	50
#
# 304	50
#
# 305	43
#
# 306	43
#
# 307	48
#
# 308	49
#
# 309	49
#
# 310	46
#
# 311	44
#
# 312	43
#
# 313	48
#
# 314	51
#
# 315	49
#
# 316	54
#
# 317	55
#
# 318	54
#
# 319	54
#
# 320	56
#
# 321	56
#
# 322	50
#
# 323	44
#
# 324	48
#
# 325	44
#
# 326	55
#
# 327	56
#
# 328	46
#
# 329	43
#
# 330	46
#
# 331	38
#
# 332	41
#
# 333	42
#
# 334	51
#
# 335	50
#
# 336	38
#
# 337	37
#
# 338	36
#
# 339	33
#
# 340	33
#
# 341	33
#
# 342	31
#
# 343	27
#
# 344	30
#
# 345	40
#
# 346	48
#
# 347	35
#
# 348	21
#
# 349	24
#
# 350	27
#
# 351	30
#
# 352	32
#
# 353	34
#
# 354	31
#
# 355	33
#
# 356	33
#
# 357	33
#
# 358	35
#
# 359	29
#
# 360	26
#
# 361	24
#
# 362	31
#
# 363	34
#
# 364	34
#
# 365	41
